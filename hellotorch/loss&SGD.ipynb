# %%
import torch

# 1. 准备数据：标准答案y_true，学生的答案y_pred
y_true = torch.tensor([1.0, 3.0, 5.0, 7.0])  # 真实值
y_pred = torch.tensor([2.0, 2.0, 6.0, 8.0])  # 模型预测值

# 2. 手动实现MSE损失（你自己就能写，完全不用黑盒）
loss_manual = ((y_pred - y_true) ** 2).mean()
print(f"手动计算的MSE损失: {loss_manual.item():.4f}")

# 3. PyTorch封装好的MSELoss，和上面手动算的结果完全一致
loss_fn = torch.nn.MSELoss(size_average=None, reduce=None, reduction= 'mean')  # 先定义损失函数
help(loss_fn)
loss_pytorch = loss_fn(y_pred, y_true)
print(f"PyTorch内置MSE损失: {loss_pytorch.item():.4f}")
# Out:
# 手动计算的MSE损失: 1.0000
# Help on MSELoss in module torch.nn.modules.loss object:
#
# class MSELoss(_Loss)
#  |  MSELoss(size_average=None, reduce=None, reduction: str = 'mean') -> None
#  |
#  |  Creates a criterion that measures the mean squared error (squared L2 norm) between
#  |  each element in the input :math:`x` and target :math:`y`.
#  |
#  |  The unreduced (i.e. with :attr:`reduction` set to ``'none'``) loss can be described as:
#  |
#  |  .. math::
#  |      \ell(x, y) = L = \{l_1,\dots,l_N\}^\top, \quad
#  |      l_n = \left( x_n - y_n \right)^2,
#  |
#  |  where :math:`N` is the batch size. If :attr:`reduction` is not ``'none'``
#  |  (default ``'mean'``), then:
#  |
#  |  .. math::
#  |      \ell(x, y) =
#  |      \begin{cases}
#  |          \operatorname{mean}(L), &  \text{if reduction} = \text{`mean';}\\
#  |          \operatorname{sum}(L),  &  \text{if reduction} = \text{`sum'.}
#  |      \end{cases}
#  |
# ...
